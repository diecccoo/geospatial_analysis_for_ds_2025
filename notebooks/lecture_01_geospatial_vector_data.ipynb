# %% [markdown]
# # Geospatial Vector Data
#
# ## goals of the lecture
# - the vector data and ESRI Shapefile
# - the geodataframe in geopandas
# - spatial projection
#
# **based on the open data of:**
#
# - [ISTAT](https://www.istat.it/it/archivio/222527) Italian National Institute of Statistic
# - [Natural Earth Data](https://www.naturalearthdata.com)
#
# ### requirements
#
# - python knowledge
# - pandas
#
# ### status
#
# *"The Earth isn't flat!!!"*
#
#
# ---

# %% [markdown]
# ## import modules

# %%
import zipfile, io
import pandas as pd
import urllib # Added import for urllib
import os
from matplotlib import pyplot as plt  #to avoid the warning message by plotting the geometries
import seaborn as sns
import warnings
warnings.simplefilter("ignore") #to avoid warning message

# %% [markdown]
# ## install geopandas

# %%
try:
  import geopandas as gpd
except ModuleNotFoundError as e:
  # !pip install geopandas==1.1.0 --break-system-packages
  import geopandas as gpd
if gpd.__version__ != "1.1.0":
  # !pip install -U geopandas==1.1.0 --break-system-packages
  import geopandas as gpd

# %%
# needed to use the method .explore in geopandas in colab
try:
  import mapclassify
except ModuleNotFoundError as e:
  # !pip install mapclassify==2.9.0
  import mapclassify
if mapclassify.__version__ != "2.9.0":
  # !pip install mapclassify==2.9.0
  import mapclassify
# Out:
# Collecting mapclassify==2.9.0
#   Downloading mapclassify-2.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify==2.9.0) (3.5)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from mapclassify==2.9.0) (2.0.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from mapclassify==2.9.0) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.12/dist-packages (from mapclassify==2.9.0) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from mapclassify==2.9.0) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify==2.9.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify==2.9.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify==2.9.0) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify==2.9.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify==2.9.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify==2.9.0) (1.17.0)
# Downloading mapclassify-2.9.0-py3-none-any.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.7/286.7 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.9.0

# %% [markdown]
# # Let's start with GeoPandas
#
# ## Importing geospatial data
#
# geopandas supports all the vector format offered by the [fiona project](https://github.com/Toblerity/Fiona) or [gdal/ogr](https://www.gdal.org/ogr_formats.html) (more formats and faster)
#
#
# we will play with the geospatial data offered by [ISTAT](https://istat.it)
#
# ### administrative borders
# [https://www.istat.it/it/archivio/222527](https://www.istat.it/it/archivio/222527)
#
# Here the zip file with all the different administrative levels of Italy
# <br/>
# [https://www.istat.it/storage/cartografia/confini_amministrativi/generalizzati/2025/Limiti01012025_g.zip](https://www.istat.it/storage/cartografia/confini_amministrativi/generalizzati/2025/Limiti01012025_g.zip)

# %% [markdown]
# Download and investigate the data

# %%
# download the data
zip_file_url = 'https://www.istat.it/storage/cartografia/confini_amministrativi/generalizzati/2025/Limiti01012025_g.zip'
zip_file_name = "Limiti01012025_g.zip"
urllib.request.urlretrieve(zip_file_url ,zip_file_name)
z = zipfile.ZipFile(zip_file_name)
# unzip the file
z.extractall()

# %% [markdown]
# Directory listening

# %%
os.listdir(".")
# Out:
# ['.config',
#  'Reg01012025_g',
#  'Limiti01012025_g.zip',
#  'RipGeo01012025_g',
#  'ProvCM01012025_g',
#  'Com01012025_g',
#  'sample_data']

# %% [markdown]
# - RipGeo01012025_g<br/>&nbsp;folder with the macro-regions of Italy
# - Reg01012025_g<br/>&nbsp;folder with the regions of Italy
# - ProvCM01012025_g<br/>&nbsp;folder with the provinces of Italy
# - Com01012025_g<br/>&nbsp;folder with the municipalities of Italy

# %% [markdown]
# #### Inspect the the macro regions

# %%
#look to the data inside the macro regions
os.chdir('RipGeo01012025_g')

# %%
#show only the files
for root, dirs, files in os.walk("."):
    for filename in files:
        print(filename)
# Out:
# RipGeo01012025_g_WGS84.shx
# RipGeo01012025_g_WGS84.prj
# RipGeo01012025_g_WGS84.shp
# RipGeo01012025_g_WGS84.dbf

# %% [markdown]
# ### ESRI Shapefile
#
# this is a *ESRI Shapefile* (an old but common used format for the geospatial vector data)
#
# The format is proprietary and some format specifications are public.
# A "ESRI Shapefile" is a collection of different files with the same name and different extensions.
#
# The public specifications are for the extensions:
#
# | extension | meaning       | content of the file                                                  |
# | --------- | ------------- | -------------------------------------------------------------------- |
# | .shp      | shape         | the geometries (point, line, polygon)                                |
# | .dbf      | database file | the attributes to associate with the geometries                      |
# | .shx      | shape indices | the indices to join the geometries with the attributes               |
# | .prj      | projection    | the rule to understand the kind of projection used by the geometries |
#
# To manage the data are _necessary_ 3 files (*.shp, .shx, and .dbf*), however the *.prj* file is crucial to analyze the data togheter with other sources.
#
# It's possibile find other kind of files
#
# more informations are [here](https://www.esri.com/library/whitepapers/pdfs/shapefile.pdf
# )

# %% [markdown]
# **read the file with gepandas**

# %%
# read the file
macroregions=gpd.read_file('RipGeo01012025_g_WGS84.shp')

# %%
type(macroregions)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ### GeoDataframe
#
# geopandas transform everything in a [GeoDataFrame](http://geopandas.org/data_structures.html#geodataframe).
#
# a geodataframe is a pandas [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) with the column "geometry" and special geospatial methods

# %%
macroregions
# Out:
#    COD_RIP     DEN_RIP    Shape_Leng    Shape_Area  \
# 0        1  Nord-ovest  2.289040e+06  5.792817e+10
# 1        2    Nord-est  2.268368e+06  6.239401e+10
# 2        3      Centro  1.978584e+06  5.803709e+10
# 3        4         Sud  2.502105e+06  7.379461e+10
# 4        5       Isole  2.772050e+06  4.993925e+10
#
#                                             geometry
# 0  MULTIPOLYGON (((568231.969 4874857.994, 568233...
# 1  MULTIPOLYGON (((618335.21 4893983.16, 618329.9...
# 2  MULTIPOLYGON (((876027.96 4525207.198, 876222....
# 3  MULTIPOLYGON (((1083304.797 4416671.21, 108333...
# 4  MULTIPOLYGON (((822779.053 3935557.494, 822909...
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['geometry'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# macroregions['COD_RIP'].plot(kind='hist', bins=20, title='COD_RIP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# macroregions['Shape_Leng'].plot(kind='hist', bins=20, title='Shape_Leng')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# macroregions['Shape_Area'].plot(kind='hist', bins=20, title='Shape_Area')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# macroregions.groupby('DEN_RIP').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# macroregions.plot(kind='scatter', x='COD_RIP', y='Shape_Leng', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# macroregions.plot(kind='scatter', x='Shape_Leng', y='Shape_Area', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['COD_RIP']
#   ys = series['Shape_Leng']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = macroregions.sort_values('COD_RIP', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('DEN_RIP')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='DEN_RIP', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('COD_RIP')
# _ = plt.ylabel('Shape_Leng')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['COD_RIP']
#   ys = series['Shape_Area']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = macroregions.sort_values('COD_RIP', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('DEN_RIP')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='DEN_RIP', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('COD_RIP')
# _ = plt.ylabel('Shape_Area')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['COD_RIP']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'COD_RIP'}, axis=1)
#               .sort_values('COD_RIP', ascending=True))
#   xs = counted['COD_RIP']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = macroregions.sort_values('COD_RIP', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('DEN_RIP')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='DEN_RIP', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('COD_RIP')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# macroregions['COD_RIP'].plot(kind='line', figsize=(8, 4), title='COD_RIP')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# macroregions['Shape_Leng'].plot(kind='line', figsize=(8, 4), title='Shape_Leng')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# macroregions['Shape_Area'].plot(kind='line', figsize=(8, 4), title='Shape_Area')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(macroregions['DEN_RIP'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(macroregions, x='COD_RIP', y='DEN_RIP', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(macroregions['DEN_RIP'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(macroregions, x='Shape_Leng', y='DEN_RIP', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(macroregions['DEN_RIP'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(macroregions, x='Shape_Area', y='DEN_RIP', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# Eg.
# calculate the area of each geometry

# %%
macroregions.geometry.length
# Out:
# 0    2.289040e+06
# 1    2.268368e+06
# 2    1.978584e+06
# 3    2.502105e+06
# 4    2.772050e+06
# dtype: float64

# %%
macroregions.geometry.area
# Out:
# 0    5.792817e+10
# 1    6.239401e+10
# 2    5.803709e+10
# 3    7.379461e+10
# 4    4.993925e+10
# dtype: float64

# %% [markdown]
# **you can plot it**

# %%
macroregions.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
macroregions.plot(figsize=(10,10))
plt.show()

# %% [markdown]
# ... and new we can use the **classic methods of the pandas DataFrame.**
#
# Eg.
#
# extract a (geo)DataFrame by filter from an attribute

# %%
macroregions['DEN_RIP']
# Out:
# 0    Nord-ovest
# 1      Nord-est
# 2        Centro
# 3           Sud
# 4         Isole
# Name: DEN_RIP, dtype: object

# %%
macroregions.DEN_RIP.unique()
# Out:
# array(['Nord-ovest', 'Nord-est', 'Centro', 'Sud', 'Isole'], dtype=object)

# %%
islands = macroregions[macroregions['DEN_RIP'] == 'Isole']

# %%
islands.plot()
plt.show()

# %%
macroregions.geom_type
# Out:
# 0    MultiPolygon
# 1    MultiPolygon
# 2    MultiPolygon
# 3    MultiPolygon
# 4    MultiPolygon
# dtype: object

# %% [markdown]
# in an *ESRI shapefile* the kind of geometry *is always the same*, but a *geodataframe* can accept *mixed geometries* for each row.

# %% [markdown]
# in our case we have a MultiPolygon
# the geometries allowed are:
#
# |geometry|images|
# |:--|--:|
# |POINT|![](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/SFA_Point.svg/51px-SFA_Point.svg.png)|
# |LINESTRING|![](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/SFA_LineString.svg/51px-SFA_LineString.svg.png)|
# |LINEARRING|![](https://raw.githubusercontent.com/napo/geospatial_course_unitn/master/docs/assets/images/linering.png)|
# |POLYGON|![](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3f/SFA_Polygon.svg/51px-SFA_Polygon.svg.png)![](https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/SFA_Polygon_with_hole.svg/51px-SFA_Polygon_with_hole.svg.png)
# |MULTIPOINT|![](https://upload.wikimedia.org/wikipedia/commons/thumb/d/d6/SFA_MultiPoint.svg/51px-SFA_MultiPoint.svg.png)
# | MULITLINESTRING|![](https://upload.wikimedia.org/wikipedia/commons/thumb/8/86/SFA_MultiLineString.svg/51px-SFA_MultiLineString.svg.png)|
# | MULTIPOLYGON |![](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/SFA_MultiPolygon_with_hole.svg/51px-SFA_MultiPolygon_with_hole.svg.png)|
# | GEOMETRYCOLLECTION |![](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1d/SFA_GeometryCollection.svg/51px-SFA_GeometryCollection.svg.png) |
#
# note: table based on the wikipedia page [WKT](https://en.wikipedia.org/wiki/Well-known_text_representation_of_geometry)

# %% [markdown]
# #### now we are ready to look how are the geometries

# %%
macroregions.geometry[0]
# Out:
# <MULTIPOLYGON (((568231.969 4874857.994, 568233.719 4874837.619, 568233.719 ...>

# %%
macroregions.DEN_RIP[0]
# Out:
# 'Nord-ovest'

# %%
macroregions.geometry[1]
# Out:
# <MULTIPOLYGON (((618335.21 4893983.16, 618329.929 4893981.66, 618312.929 489...>

# %%
macroregions.DEN_RIP[1]
# Out:
# 'Nord-est'

# %%
macroregions.geometry[2]
# Out:
# <MULTIPOLYGON (((876027.96 4525207.198, 876222.021 4525055.199, 876255.084 4...>

# %%
macroregions.DEN_RIP[2]
# Out:
# 'Centro'

# %%
macroregions.geometry[3]
# Out:
# <MULTIPOLYGON (((1083304.797 4416671.21, 1083333.24 4416669.887, 1083424.902...>

# %%
macroregions.DEN_RIP[3]
# Out:
# 'Sud'

# %%
macroregions.geometry[4]
# Out:
# <MULTIPOLYGON (((822779.053 3935557.494, 822909.27 3935316.384, 822901.365 3...>

# %%
macroregions.DEN_RIP[4]
# Out:
# 'Isole'

# %% [markdown]
# #### Do you want know the centroid position of each geometry?

# %%
macroregions.geometry.centroid
# Out:
# 0    POINT (478136.136 5011442.788)
# 1    POINT (702039.161 5039725.527)
# 2    POINT (756686.712 4757568.884)
# 3    POINT (1061520.288 4529729.45)
# 4    POINT (736468.577 4300314.379)
# dtype: geometry

# %% [markdown]
# the output of the geometries is in [well knowtext format (WKT)](https://en.wikipedia.org/wiki/Well-known_text_representation_of_geometry)
#
# but ... how are expressed the coordinates??
# we have to know the Coordinate Reference System (CRS)

# %% [markdown]
# # SPATIAL PROJECTIONS
#
# **CRS** = *Coordinate Reference System*
#
# ## The Earth isn't FLAT
# ### The true size
# ![](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/images/truesize.gif)
#
# https://thetruesize.com/

# %% [markdown]
# ## How to convert in latitude/longitude?

# %%
macroregions.crs
# Out:
# <Projected CRS: EPSG:32632>
# Name: WGS 84 / UTM zone 32N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 6°E and 12°E, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Austria. Cameroon. Denmark. Equatorial Guinea. France. Gabon. Germany. Italy. Libya. Liechtenstein. Monaco. Netherlands. Niger. Nigeria. Norway. Sao Tome and Principe. Svalbard. Sweden. Switzerland. Tunisia. Vatican City State.
# - bounds: (6.0, 0.0, 12.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 32N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## EPSG?
# European Petroleum Survey Group  (1986-2005)<br/>
# [IOGP](https://www.iogp.org/about-us/) - International Association of Oil & Gas Producers (2005-now)
#
# An important project is the [EPSG registry](http://www.epsg-registry.org/) - the dataset of geodetic parameters
#
# [http://epsg.io/32632](http://epsg.io/32632)
#
# ![](https://github.com/napo/geospatial_course_unitn/raw/master/docs/assets/images/epsg32632.png)
#
# ![](https://upload.wikimedia.org/wikipedia/commons/b/b9/Usgs_map_traverse_mercator.PNG)
#
# ![](https://upload.wikimedia.org/wikipedia/commons/e/ed/Utm-zones.jpg)

# %%
macroregions.geometry.centroid.to_crs(epsg=4326)
# Out:
# 0     POINT (8.72135 45.25614)
# 1     POINT (11.58522 45.4818)
# 2     POINT (12.1454 42.92753)
# 3    POINT (15.64709 40.72676)
# 4    POINT (11.72373 38.81989)
# dtype: geometry

# %%
macroregions.to_crs(epsg=4326).geometry[1]
# Out:
# <MULTIPOLYGON (((10.481 44.189, 10.481 44.189, 10.48 44.189, 10.48 44.19, 10...>

# %%
macroregions.geometry[1]
# Out:
# <MULTIPOLYGON (((618335.21 4893983.16, 618329.929 4893981.66, 618312.929 489...>

# %%
macroregions.to_crs(epsg=6875).geometry[1]
# Out:
# <MULTIPOLYGON (((6878712.414 4888653.889, 6878707.088 4888652.585, 6878690.2...>

# %% [markdown]
# ### WGS84 VS ETRS89
#
# |  [WGS84](https://epsg.io/4326)  |  [ETRS89](https://epsg.io/4258) |
# |---|---|
# |  ![](https://github.com/napo/geospatial_course_unitn/blob/master/images/wgs84_coverage.png?raw=true) | ![](https://github.com/napo/geospatial_course_unitn/blob/master/images/etrs89_coverage.png?raw=true)

# %% [markdown]
# ## exploring a .prj file

# %%
f=open('RipGeo01012025_g_WGS84.prj','r')

# %%
f.read()
# Out:
# 'PROJCS["WGS_1984_UTM_Zone_32N",GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",9.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]'

# %% [markdown]
# ... like here
#
# [http://epsg.io/32632.wkt](http://epsg.io/32632.wkt)
#
# here a "pretty" version
#
# [http://epsg.io/32632.wkt](http://epsg.io/32632.wkt)

# %% [markdown]
# ## save the geodataframe

# %%
macroregions.to_crs(epsg=4326).to_file('macro_regions.geojson',driver='GeoJSON') #possiamo controllare il file dopo averlo creato su geojson.io

# %%
macroregions["lon"] = macroregions.geometry.to_crs(epsg=4326).centroid.x

# %%
macroregions["lat"] = macroregions.geometry.to_crs(epsg=4326).centroid.y

# %%
macroregions
# Out:
#    COD_RIP     DEN_RIP    Shape_Leng    Shape_Area  \
# 0        1  Nord-ovest  2.289040e+06  5.792817e+10
# 1        2    Nord-est  2.268368e+06  6.239401e+10
# 2        3      Centro  1.978584e+06  5.803709e+10
# 3        4         Sud  2.502105e+06  7.379461e+10
# 4        5       Isole  2.772050e+06  4.993925e+10
#
#                                             geometry        lon        lat
# 0  MULTIPOLYGON (((568231.969 4874857.994, 568233...   8.729769  45.257521
# 1  MULTIPOLYGON (((618335.21 4893983.16, 618329.9...  11.593213  45.490269
# 2  MULTIPOLYGON (((876027.96 4525207.198, 876222....  12.131197  42.932941
# 3  MULTIPOLYGON (((1083304.797 4416671.21, 108333...  15.619795  40.740668
# 4  MULTIPOLYGON (((822779.053 3935557.494, 822909...  11.625945  38.819971

# %% [markdown]
# and visualize on [https://geojson.io](https://geojson.io)
#
# ![](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/images/geojsonio.jpg)

# %% [markdown]
# # Other Examples
#
# ## Explore Natural Earth Data
# <img src="https://www.naturalearthdata.com/wp-content/uploads/2009/08/NEV-Logo-Black.png" width="450px"/>
#
# [https://www.naturalearthdata.com/](https://www.naturalearthdata.com/)

# %% [markdown]
# Check the nice dataset about disputed areas
#
# ![](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/images/naturalearth_disputed.jpg)
#
# Start from this [document](https://www.naturalearthdata.com/about/disputed-boundaries-policy/)

# %% [markdown]
# Investigate the data

# %%
url_naturalearth_data_disputed_areas = "https://github.com/napo/geospatialcourse2025/raw/refs/heads/main/data/ne_10m_admin_0_disputed_areas.zip"
disputed_areas = gpd.read_file(url_naturalearth_data_disputed_areas)

# %%
disputed_areas.head(3)
# Out:
#                        featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  \
# 0              Admin-0 claim area          0          5      India    IND
# 1              Admin-0 claim area          0          5      China    CH1
# 2  Admin-0 breakaway and disputed          0          4     Israel    IS1
#
#    ADM0_DIF  LEVEL      TYPE   TLC   ADMIN  ...     FCLASS_TR     FCLASS_ID  \
# 0         0      5  Disputed  None   India  ...  Unrecognized          None
# 1         1      5  Disputed  None   China  ...  Unrecognized          None
# 2         1      5  Disputed  None  Israel  ...  Unrecognized  Unrecognized
#
#       FCLASS_PL     FCLASS_GR     FCLASS_IT     FCLASS_NL     FCLASS_SE  \
# 0          None          None          None          None          None
# 1          None          None          None          None          None
# 2  Unrecognized  Unrecognized  Unrecognized  Unrecognized  Unrecognized
#
#       FCLASS_BD     FCLASS_UA  \
# 0          None          None
# 1          None          None
# 2  Unrecognized  Unrecognized
#
#                                             geometry
# 0  POLYGON ((77.80035 35.49541, 77.81533 35.47334...
# 1  POLYGON ((77.80035 35.49541, 77.82949 35.49179...
# 2  POLYGON ((34.24835 31.21145, 34.2644 31.22419,...
#
# [3 rows x 169 columns]

# %%
admins = disputed_areas.ADMIN.value_counts()
admins = admins.sort_values(ascending=False)
admins
# Out:
# ADMIN
# India                                   8
# Israel                                  7
# Spain                                   7
# French Southern and Antarctic Lands     5
# South Korea                             3
# Croatia                                 3
# China                                   3
# Palestine                               2
# France                                  2
# Pakistan                                2
# Ukraine                                 2
# Georgia                                 2
# Egypt                                   2
# Russia                                  2
# Belize                                  2
# Bhutan                                  2
# Guyana                                  2
# South Georgia and the Islands           2
# United States Minor Outlying Islands    2
# British Indian Ocean Territory          2
# Kenya                                   1
# Syria                                   1
# Somaliland                              1
# Western Sahara                          1
# North Korea                             1
# Sudan                                   1
# Gibraltar                               1
# Moldova                                 1
# Brazilian Island                        1
# US Naval Base Guantanamo Bay            1
# Morocco                                 1
# Kosovo                                  1
# Azerbaijan                              1
# Southern Patagonian Ice Field           1
# Cyprus No Mans Area                     1
# Siachen Glacier                         1
# South Sudan                             1
# Bir Tawil                               1
# Brazil                                  1
# Baykonur Cosmodrome                     1
# Northern Cyprus                         1
# Malaysia                                1
# Taiwan                                  1
# American Samoa                          1
# Falkland Islands                        1
# Spratly Islands                         1
# Venezuela                               1
# United Kingdom                          1
# Japan                                   1
# Iran                                    1
# Bajo Nuevo Bank (Petrel Is.)            1
# Serranilla Bank                         1
# Greenland                               1
# Gabon                                   1
# New Caledonia                           1
# Scarborough Reef                        1
# Eritrea                                 1
# Name: count, dtype: int64

# %% [markdown]
# plot it

# %%
plt.figure(figsize=(10, 10))
plt.barh(admins.index, admins.values, color='skyblue')
plt.xlabel('Number of areas')
plt.ylabel('Administration')
plt.title('number of disputed areas and current territories')
plt.gca().invert_yaxis()
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %%
disputed_areas.explore(tooltip="NAME")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c89bb359d73f37ebd845e96b6551eb3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c89bb359d73f37ebd845e96b6551eb3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c89bb359d73f37ebd845e96b6551eb3e = L.map(
#                 &quot;map_c89bb359d73f37ebd845e96b6551eb3e&quot;,
#                 {
#                     center: [10.680039781000062, 0.486400663000083],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c89bb359d73f37ebd845e96b6551eb3e);
#
#
#
#
#
#             var tile_layer_29fb7fb3cc7927425fd513b728c1326b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29fb7fb3cc7927425fd513b728c1326b.addTo(map_c89bb359d73f37ebd845e96b6551eb3e);
#
#
#             map_c89bb359d73f37ebd845e96b6551eb3e.fitBounds(
#                 [[-59.47275155999995, -171.0865372389999], [80.83283112200007, 172.05933856500008]],
#                 {}
#             );
#
#
#         function geo_json_2047cfc78972aabccb2ce2b836430f35_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_2047cfc78972aabccb2ce2b836430f35_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_2047cfc78972aabccb2ce2b836430f35_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_2047cfc78972aabccb2ce2b836430f35_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_2047cfc78972aabccb2ce2b836430f35_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_2047cfc78972aabccb2ce2b836430f35.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2047cfc78972aabccb2ce2b836430f35_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2047cfc78972aabccb2ce2b836430f35 = L.geoJson(null, {
#                 onEachFeature: geo_json_2047cfc78972aabccb2ce2b836430f35_onEachFeature,
#
#                 style: geo_json_2047cfc78972aabccb2ce2b836430f35_styler,
#                 pointToLayer: geo_json_2047cfc78972aabccb2ce2b836430f35_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_2047cfc78972aabccb2ce2b836430f35_add (data) {
#             geo_json_2047cfc78972aabccb2ce2b836430f35
#                 .addData(data);
#         }
#             geo_json_2047cfc78972aabccb2ce2b836430f35_add({&quot;bbox&quot;: [-171.0865372389999, -59.47275155999995, 172.05933856500008, 80.83283112200007], &quot;features&quot;: [{&quot;bbox&quot;: [73.77485559100006, 32.30058686000011, 79.24015507000018, 35.49540557900012], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[77.80034631400014, 35.49540557900012], [77.81533247900012, 35.47333974200002], [77.83424605300007, 35.452152405000064], [77.85708703600005, 35.43659779900004], [77.883

# %%
url_naturalearth_data_disputed_bordes = "https://github.com/napo/geospatialcourse2025/raw/main/data/ne_10m_admin_0_disputed_areas.zip"
disputed_borders = gpd.read_file(url_naturalearth_data_disputed_bordes)

# %%
disputed_borders.head(3)
# Out:
#                        featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  \
# 0              Admin-0 claim area          0          5      India    IND
# 1              Admin-0 claim area          0          5      China    CH1
# 2  Admin-0 breakaway and disputed          0          4     Israel    IS1
#
#    ADM0_DIF  LEVEL      TYPE   TLC   ADMIN  ...     FCLASS_TR     FCLASS_ID  \
# 0         0      5  Disputed  None   India  ...  Unrecognized          None
# 1         1      5  Disputed  None   China  ...  Unrecognized          None
# 2         1      5  Disputed  None  Israel  ...  Unrecognized  Unrecognized
#
#       FCLASS_PL     FCLASS_GR     FCLASS_IT     FCLASS_NL     FCLASS_SE  \
# 0          None          None          None          None          None
# 1          None          None          None          None          None
# 2  Unrecognized  Unrecognized  Unrecognized  Unrecognized  Unrecognized
#
#       FCLASS_BD     FCLASS_UA  \
# 0          None          None
# 1          None          None
# 2  Unrecognized  Unrecognized
#
#                                             geometry
# 0  POLYGON ((77.80035 35.49541, 77.81533 35.47334...
# 1  POLYGON ((77.80035 35.49541, 77.82949 35.49179...
# 2  POLYGON ((34.24835 31.21145, 34.2644 31.22419,...
#
# [3 rows x 169 columns]

# %%
longest = disputed_borders.to_crs(epsg=3857).geometry.length.max()
shortest = disputed_borders.to_crs(epsg=3857).geometry.length.min()

# %%
longest_border_disputed = disputed_borders[disputed_borders.to_crs(epsg=3857).geometry.length == longest]
longest_border_disputed
# Out:
#             featurecla  scalerank  LABELRANK      SOVEREIGNT SOV_A3  ADM0_DIF  \
# 71  Admin-0 claim area          5          5  United Kingdom    GB1         1
#
#     LEVEL      TYPE TLC             ADMIN  ... FCLASS_TR  FCLASS_ID FCLASS_PL  \
# 71      2  Disputed   1  Falkland Islands  ...      None       None      None
#
#    FCLASS_GR  FCLASS_IT FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 71      None       None      None      None       None      None
#
#                                              geometry
# 71  MULTIPOLYGON (((-59.69445 -52.2081, -59.67687 ...
#
# [1 rows x 169 columns]

# %%
shortest_border_disputed = disputed_borders[disputed_borders.to_crs(epsg=3857).geometry.length == shortest]
shortest_border_disputed
# Out:
#             featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  \
# 93  Admin-0 claim area          6          9      Spain    ESP         0
#
#     LEVEL      TYPE   TLC  ADMIN  ... FCLASS_TR  FCLASS_ID FCLASS_PL  \
# 93      5  Disputed  None  Spain  ...      None       None      None
#
#    FCLASS_GR  FCLASS_IT FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 93      None       None      None      None       None      None
#
#                                              geometry
# 93  MULTIPOLYGON (((-3.90296 35.21531, -3.90233 35...
#
# [1 rows x 169 columns]

# %%
longest_border_disputed
# Out:
#             featurecla  scalerank  LABELRANK      SOVEREIGNT SOV_A3  ADM0_DIF  \
# 71  Admin-0 claim area          5          5  United Kingdom    GB1         1
#
#     LEVEL      TYPE TLC             ADMIN  ... FCLASS_TR  FCLASS_ID FCLASS_PL  \
# 71      2  Disputed   1  Falkland Islands  ...      None       None      None
#
#    FCLASS_GR  FCLASS_IT FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 71      None       None      None      None       None      None
#
#                                              geometry
# 71  MULTIPOLYGON (((-59.69445 -52.2081, -59.67687 ...
#
# [1 rows x 169 columns]

# %%
longest_border_disputed.explore(tooltip=['NAME','ADMIN','SOVEREIGNT','TYPE'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d259cb379651782b4cf87d1d8cf2f2b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d259cb379651782b4cf87d1d8cf2f2b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d259cb379651782b4cf87d1d8cf2f2b7 = L.map(
#                 &quot;map_d259cb379651782b4cf87d1d8cf2f2b7&quot;,
#                 {
#                     center: [-51.974297784499925, -59.52623450449994],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d259cb379651782b4cf87d1d8cf2f2b7);
#
#
#
#
#
#             var tile_layer_7e813cfbe4ffbc167a824a00c0e45b87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e813cfbe4ffbc167a824a00c0e45b87.addTo(map_d259cb379651782b4cf87d1d8cf2f2b7);
#
#
#             map_d259cb379651782b4cf87d1d8cf2f2b7.fitBounds(
#                 [[-52.93539804499994, -61.31818600199995], [-51.01319752399991, -57.73428300699993]],
#                 {}
#             );
#
#
#         function geo_json_3e27cf94685f1a12ea5f7f02934348c6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3e27cf94685f1a12ea5f7f02934348c6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3e27cf94685f1a12ea5f7f02934348c6_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_3e27cf94685f1a12ea5f7f02934348c6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3e27cf94685f1a12ea5f7f02934348c6_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3e27cf94685f1a12ea5f7f02934348c6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3e27cf94685f1a12ea5f7f02934348c6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3e27cf94685f1a12ea5f7f02934348c6 = L.geoJson(null, {
#                 onEachFeature: geo_json_3e27cf94685f1a12ea5f7f02934348c6_onEachFeature,
#
#                 style: geo_json_3e27cf94685f1a12ea5f7f02934348c6_styler,
#                 pointToLayer: geo_json_3e27cf94685f1a12ea5f7f02934348c6_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_3e27cf94685f1a12ea5f7f02934348c6_add (data) {
#             geo_json_3e27cf94685f1a12ea5f7f02934348c6
#                 .addData(data);
#         }
#             geo_json_3e27cf94685f1a12ea5f7f02934348c6_add({&quot;bbox&quot;: [-61.31818600199995, -52.93539804499994, -57.73428300699993, -51.01319752399991], &quot;features&quot;: [{&quot;bbox&quot;: [-61.31818600199995, -52.93539804499994, -57.73428300699993, -51.01319752399991], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-59.69444739499994, -52.208103122999944], [-59.67686926999994, -52.21559010199991], [-59.67918860599991, -52.22926197699991], [-59.69326738199993, -52.2424455

# %%
shortest_border_disputed.explore(tooltip=['NAME','ADMIN','SOVEREIGNT','TYPE'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49fe24ddc8d031cbf9ef66a9e7845683 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49fe24ddc8d031cbf9ef66a9e7845683&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49fe24ddc8d031cbf9ef66a9e7845683 = L.map(
#                 &quot;map_49fe24ddc8d031cbf9ef66a9e7845683&quot;,
#                 {
#                     center: [35.216324027500065, -3.901474898499913],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_49fe24ddc8d031cbf9ef66a9e7845683);
#
#
#
#
#
#             var tile_layer_9227e644269ed736fef9188292ee70f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9227e644269ed736fef9188292ee70f3.addTo(map_49fe24ddc8d031cbf9ef66a9e7845683);
#
#
#             map_49fe24ddc8d031cbf9ef66a9e7845683.fitBounds(
#                 [[35.214787124000054, -3.903131789999918], [35.217860931000075, -3.899818006999908]],
#                 {}
#             );
#
#
#         function geo_json_df7667307a2d4da7378f80480044fd2f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_df7667307a2d4da7378f80480044fd2f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_df7667307a2d4da7378f80480044fd2f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_df7667307a2d4da7378f80480044fd2f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_df7667307a2d4da7378f80480044fd2f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_df7667307a2d4da7378f80480044fd2f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_df7667307a2d4da7378f80480044fd2f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_df7667307a2d4da7378f80480044fd2f = L.geoJson(null, {
#                 onEachFeature: geo_json_df7667307a2d4da7378f80480044fd2f_onEachFeature,
#
#                 style: geo_json_df7667307a2d4da7378f80480044fd2f_styler,
#                 pointToLayer: geo_json_df7667307a2d4da7378f80480044fd2f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_df7667307a2d4da7378f80480044fd2f_add (data) {
#             geo_json_df7667307a2d4da7378f80480044fd2f
#                 .addData(data);
#         }
#             geo_json_df7667307a2d4da7378f80480044fd2f_add({&quot;bbox&quot;: [-3.903131789999918, 35.214787124000054, -3.899818006999908, 35.217860931000075], &quot;features&quot;: [{&quot;bbox&quot;: [-3.903131789999918, 35.214787124000054, -3.899818006999908, 35.217860931000075], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-3.902962458999923, 35.21530963200007], [-3.9023293799999124, 35.21590471400009], [-3.9019568499999195, 35.21546445200005], [-3.90253257899991, 35.214787124000

# %% [markdown]
# ## Exercise
# 1. load the shapefile of ISTAT with the information of the provinces
#     - filter it for an italian provice at your choice (eg. Trento)
#     - plot it
# 2. load the shapefile of ISTAT with the informations of the muncipalities
#     - identify the cities of the province selected with the biggest and smallest area
#     - extract all the centroids of the areas expressed in WGS84
#     - select all the muncipalities of the Province of Trento
#     - extract a representative point for the area of each municipality converted in WGS84
#     - suggestion: .representative_point()
#     - save the points in a GeoJSON file
#     - calculate the distance on the geodentic between the municipality with the big area and smallest area by using the centroid
# 3.  download the shapefile of the [lakes and bodies of water of Trentino](https://github.com/napo/geospatialcourse2025/raw/refs/heads/main/data/lakes_bodies_of_water_trentino.zip) - projection Monte Mario zone 1
#     - convert in WGS84 and create a geojson
